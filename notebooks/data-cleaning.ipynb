# %% [markdown]
# ## Nettoyage de données

# %%
from pyspark.sql import functions as F
from modules.spark import spark

# %%
df = spark.read.csv('../data/processed/data-cleaned', header=True, inferSchema=True)

# %%
df.columns
# Out:
# ['Type',
#  'ShippingMode',
#  'LateDeliveryRisk',
#  'CategoryName',
#  'CustomerSegment',
#  'OrderItemTotal',
#  'OrderRegion',
#  'ShippingMonthName']

# %% [markdown]
# ### Gérer les valeurs manquantes.
#
# Dejà fait

# %% [markdown]
# ### Équilibrer les classes.

# %%
df.count()
# Out:
# 170912

# %%
df.groupBy('LateDeliveryRisk').count().show()
# Out:
# +----------------+-----+
# |LateDeliveryRisk|count|
# +----------------+-----+
# |               1|97946|
# |               0|72966|
# +----------------+-----+

# %%
class_0 = df.filter(F.col("LateDeliveryRisk") == 0)
class_1 = df.filter(F.col("LateDeliveryRisk") == 1)

ratio = class_0.count() / class_1.count()

new_class_1 = class_1.sample(withReplacement=False, fraction=ratio)

df_equilibred = class_0.union(new_class_1)

# %%
new_class_0 = df_equilibred.filter(F.col("LateDeliveryRisk") == 0).count()
new_class_1 = df_equilibred.filter(F.col("LateDeliveryRisk") == 1).count()

print(new_class_0)
print(new_class_1)
# Out:
# 72966
# 73179

# %%
df_equilibred.columns
# Out:
# ['Type',
#  'ShippingMode',
#  'LateDeliveryRisk',
#  'CategoryName',
#  'CustomerSegment',
#  'OrderItemTotal',
#  'OrderRegion',
#  'ShippingMonthName']

# %%
df_equilibred.write.csv('../data/processed/data-balanced', header=True)

# %% [markdown]
# ### Encoder les variables catégorielles.

# %% [markdown]
# - Encodage avec StringIndexer

# %%
from pyspark.ml.feature import StringIndexer
from pyspark.ml import Pipeline

indexers = [
    StringIndexer(inputCol="Type", outputCol="Type_index"),
    StringIndexer(inputCol="ShippingMode", outputCol="ShippingMode_index"),
    StringIndexer(inputCol="CategoryName", outputCol="CategoryName_index"),
    StringIndexer(inputCol="CustomerSegment", outputCol="CustomerSegment_index"),
    StringIndexer(inputCol="OrderRegion", outputCol="OrderRegion_index"),
    StringIndexer(inputCol="ShippingMonthName", outputCol="ShippingMonthName_index"),
]

pipeline = Pipeline(stages=indexers)

df_indexed = pipeline.fit(df_equilibred).transform(df_equilibred)
df_indexed.show()
# Out:
# +-------+--------------+----------------+---------------+---------------+--------------+---------------+-----------------+----------+------------------+------------------+---------------------+-----------------+-----------------------+
# |   Type|  ShippingMode|LateDeliveryRisk|   CategoryName|CustomerSegment|OrderItemTotal|    OrderRegion|ShippingMonthName|Type_index|ShippingMode_index|CategoryName_index|CustomerSegment_index|OrderRegion_index|ShippingMonthName_index|
# +-------+--------------+----------------+---------------+---------------+--------------+---------------+-----------------+----------+------------------+------------------+---------------------+-----------------+-----------------------+
# |PAYMENT|Standard Class|               0|  Shop By Sport|       Consumer|   179.9600067|Central America|              May|       2.0|               0.0|               8.0|                  0.0|              0.0|                    4.0|
# |PAYMENT|Standard Class|               0|Women's Apparel|       Consumer|         225.0|Central America|              May|       2.0|               0.0|               2.0|                  0.0|              0.0|                    4.0|
# |PAYMENT|Standard Class|               0|Women's Apparel|       Consumer|         220.0|      Caribbean|          January|       2.0|               0.0|               2.0|                  0.0|              7.0|                    0.0|
# |PAYMENT|Standard Class|               0|  Shop By Sport|       Consumer|   175.9600067|  South America|              May|       2.0|               0.0|               8.0|                  0.0|              2.0|                    4.0|
# |PAYMENT|Standard Class|               0|  Shop By Sport|       Consumer|   175.9600067|  South America|         February|       2.0|               0.0|               8.0|                  0.0|              2.0|                    8.0|
# |PAYMENT|Standard Class|               0|Women's Apparel|       Consumer|         220.0|  South America|         February|       2.0|               0.0|               2.0|                  0.0|              2.0|                    8.0|
# |PAYMENT|Standard Class|               0|  Shop By Sport|       Consumer|   173.9600067|  South America|            April|       2.0|               0.0|               8.0|                  0.0|              2.0|                    5.0|
# |PAYMENT|Standard Class|               0|Women's Apparel|       Consumer|         212.5|Central America|          January|       2.0|               0.0|               2.0|                  0.0|              0.0|                    0.0|
# |PAYMENT|Standard Class|               0|Women's Apparel|       Consumer|         212.5|Central America|             June|       2.0|               0.0|               2.0|                  0.0|              0.0|                    7.0|
# |PAYMENT|Standard Class|               0|  Shop By Sport|       Consumer|   169.9600067|  South America|              May|       2.0|               0.0|               8.0|                  0.0|              2.0|                    4.0|
# |PAYMENT|Standard Class|               0|  Shop By Sport|       Consumer|   167.9600067|Central America|          January|       2.0|               0.0|               8.0|                  0.0|              0.0|                    0.0|
# |PAYMENT|Standard Class|               0|Women's Apparel|       Consumer|         210.0|Central America|              May|       2.0|               0.0|               2.0|                  0.0|              0.0|                    4.0|
# |PAYMENT|Standard Class|               0|  Shop By Sport|       Consumer|   167.9600067|  South America|         February|       2.0|               0.0|               8.0|                  0.0|              2.0|                    8.0|
# |PAYMENT|Standard Class|               0|  Shop By Sport|       Consumer|   163.9600067|Central America|            April|       2.0|               0.0|               8.0|                  0.0|              0.0|                    5.0|
# |PAYMENT|Standard Class|               0|  Shop By Sport|       Consumer|   163.9600067|Central America|          January|       2.0|               0.0|               8.0|                  0.0|              0.0|                    0.0|
# |PAYMENT|Standard Class|               0|Women's Apparel|       Consumer|         200.0|Central America|          January|       2.0|               0.0|               2.0|                  0.0|              0.0|                    0.0|
# |PAYMENT|Standard Class|               0|Women's Apparel|       Consumer|         187.5|Central America|         February|       2.0|               0.0|               2.0|                  0.0|              0.0|                    8.0|
# |PAYMENT|Standard Class|               0|    Accessories|       Consumer|   121.1999969|Central America|         February|       2.0|               0.0|              10.0|                  0.0|              0.0|                    8.0|
# |PAYMENT|Standard Class|               0|    Accessories|       Consumer|   112.4599991|      Caribbean|            March|       2.0|               0.0|              10.0|                  0.0|              7.0|                    3.0|
# |PAYMENT|Standard Class|               0|    Accessories|       Consumer|   106.2099991|      Caribbean|            April|       2.0|               0.0|              10.0|                  0.0|              7.0|                    5.0|
# +-------+--------------+----------------+---------------+---------------+--------------+---------------+-----------------+----------+------------------+------------------+---------------------+-----------------+-----------------------+
# only showing top 20 rows

# %%
df_indexed.write.csv('../data/processed/data-indexed', header=True)

# %% [markdown]
# - Encodage One-Hot

# %%
from pyspark.ml.feature import OneHotEncoder

encoder = OneHotEncoder(
    inputCols=["Type_index", "ShippingMode_index", "CategoryName_index", "CustomerSegment_index", "OrderRegion_index", "ShippingMonthName_index"],
    outputCols=["Type_vec", "ShippingMode_vec", "CategoryName_vec", "CustomerSegment_vec", "OrderRegion_vec", "ShippingMonthName_vec"]
)

pipeline = Pipeline(stages=[encoder])

df_encoded = pipeline.fit(df_indexed).transform(df_indexed)
df_encoded.show(truncate=False)
# Out:
# +-------+--------------+----------------+---------------+---------------+--------------+---------------+-----------------+----------+------------------+------------------+---------------------+-----------------+-----------------------+-------------+----------------+----------------+-------------------+---------------+---------------------+
# |Type   |ShippingMode  |LateDeliveryRisk|CategoryName   |CustomerSegment|OrderItemTotal|OrderRegion    |ShippingMonthName|Type_index|ShippingMode_index|CategoryName_index|CustomerSegment_index|OrderRegion_index|ShippingMonthName_index|Type_vec     |ShippingMode_vec|CategoryName_vec|CustomerSegment_vec|OrderRegion_vec|ShippingMonthName_vec|
# +-------+--------------+----------------+---------------+---------------+--------------+---------------+-----------------+----------+------------------+------------------+---------------------+-----------------+-----------------------+-------------+----------------+----------------+-------------------+---------------+---------------------+
# |PAYMENT|Standard Class|0               |Shop By Sport  |Consumer       |179.9600067   |Central America|May              |2.0       |0.0               |8.0               |0.0                  |0.0              |4.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[8],[1.0])  |(2,[0],[1.0])      |(22,[0],[1.0]) |(11,[4],[1.0])       |
# |PAYMENT|Standard Class|0               |Women's Apparel|Consumer       |225.0         |Central America|May              |2.0       |0.0               |2.0               |0.0                  |0.0              |4.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[2],[1.0])  |(2,[0],[1.0])      |(22,[0],[1.0]) |(11,[4],[1.0])       |
# |PAYMENT|Standard Class|0               |Women's Apparel|Consumer       |220.0         |Caribbean      |January          |2.0       |0.0               |2.0               |0.0                  |7.0              |0.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[2],[1.0])  |(2,[0],[1.0])      |(22,[7],[1.0]) |(11,[0],[1.0])       |
# |PAYMENT|Standard Class|0               |Shop By Sport  |Consumer       |175.9600067   |South America  |May              |2.0       |0.0               |8.0               |0.0                  |2.0              |4.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[8],[1.0])  |(2,[0],[1.0])      |(22,[2],[1.0]) |(11,[4],[1.0])       |
# |PAYMENT|Standard Class|0               |Shop By Sport  |Consumer       |175.9600067   |South America  |February         |2.0       |0.0               |8.0               |0.0                  |2.0              |8.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[8],[1.0])  |(2,[0],[1.0])      |(22,[2],[1.0]) |(11,[8],[1.0])       |
# |PAYMENT|Standard Class|0               |Women's Apparel|Consumer       |220.0         |South America  |February         |2.0       |0.0               |2.0               |0.0                  |2.0              |8.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[2],[1.0])  |(2,[0],[1.0])      |(22,[2],[1.0]) |(11,[8],[1.0])       |
# |PAYMENT|Standard Class|0               |Shop By Sport  |Consumer       |173.9600067   |South America  |April            |2.0       |0.0               |8.0               |0.0                  |2.0              |5.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[8],[1.0])  |(2,[0],[1.0])      |(22,[2],[1.0]) |(11,[5],[1.0])       |
# |PAYMENT|Standard Class|0               |Women's Apparel|Consumer       |212.5         |Central America|January          |2.0       |0.0               |2.0               |0.0                  |0.0              |0.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[2],[1.0])  |(2,[0],[1.0])      |(22,[0],[1.0]) |(11,[0],[1.0])       |
# |PAYMENT|Standard Class|0               |Women's Apparel|Consumer       |212.5         |Central America|June             |2.0       |0.0               |2.0               |0.0                  |0.0              |7.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[2],[1.0])  |(2,[0],[1.0])      |(22,[0],[1.0]) |(11,[7],[1.0])       |
# |PAYMENT|Standard Class|0               |Shop By Sport  |Consumer       |169.9600067   |South America  |May              |2.0       |0.0               |8.0               |0.0                  |2.0              |4.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[8],[1.0])  |(2,[0],[1.0])      |(22,[2],[1.0]) |(11,[4],[1.0])       |
# |PAYMENT|Standard Class|0               |Shop By Sport  |Consumer       |167.9600067   |Central America|January          |2.0       |0.0               |8.0               |0.0                  |0.0              |0.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[8],[1.0])  |(2,[0],[1.0])      |(22,[0],[1.0]) |(11,[0],[1.0])       |
# |PAYMENT|Standard Class|0               |Women's Apparel|Consumer       |210.0         |Central America|May              |2.0       |0.0               |2.0               |0.0                  |0.0              |4.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[2],[1.0])  |(2,[0],[1.0])      |(22,[0],[1.0]) |(11,[4],[1.0])       |
# |PAYMENT|Standard Class|0               |Shop By Sport  |Consumer       |167.9600067   |South America  |February         |2.0       |0.0               |8.0               |0.0                  |2.0              |8.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[8],[1.0])  |(2,[0],[1.0])      |(22,[2],[1.0]) |(11,[8],[1.0])       |
# |PAYMENT|Standard Class|0               |Shop By Sport  |Consumer       |163.9600067   |Central America|April            |2.0       |0.0               |8.0               |0.0                  |0.0              |5.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[8],[1.0])  |(2,[0],[1.0])      |(22,[0],[1.0]) |(11,[5],[1.0])       |
# |PAYMENT|Standard Class|0               |Shop By Sport  |Consumer       |163.9600067   |Central America|January          |2.0       |0.0               |8.0               |0.0                  |0.0              |0.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[8],[1.0])  |(2,[0],[1.0])      |(22,[0],[1.0]) |(11,[0],[1.0])       |
# |PAYMENT|Standard Class|0               |Women's Apparel|Consumer       |200.0         |Central America|January          |2.0       |0.0               |2.0               |0.0                  |0.0              |0.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[2],[1.0])  |(2,[0],[1.0])      |(22,[0],[1.0]) |(11,[0],[1.0])       |
# |PAYMENT|Standard Class|0               |Women's Apparel|Consumer       |187.5         |Central America|February         |2.0       |0.0               |2.0               |0.0                  |0.0              |8.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[2],[1.0])  |(2,[0],[1.0])      |(22,[0],[1.0]) |(11,[8],[1.0])       |
# |PAYMENT|Standard Class|0               |Accessories    |Consumer       |121.1999969   |Central America|February         |2.0       |0.0               |10.0              |0.0                  |0.0              |8.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[10],[1.0]) |(2,[0],[1.0])      |(22,[0],[1.0]) |(11,[8],[1.0])       |
# |PAYMENT|Standard Class|0               |Accessories    |Consumer       |112.4599991   |Caribbean      |March            |2.0       |0.0               |10.0              |0.0                  |7.0              |3.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[10],[1.0]) |(2,[0],[1.0])      |(22,[7],[1.0]) |(11,[3],[1.0])       |
# |PAYMENT|Standard Class|0               |Accessories    |Consumer       |106.2099991   |Caribbean      |April            |2.0       |0.0               |10.0              |0.0                  |7.0              |5.0                    |(3,[2],[1.0])|(3,[0],[1.0])   |(48,[10],[1.0]) |(2,[0],[1.0])      |(22,[7],[1.0]) |(11,[5],[1.0])       |
# +-------+--------------+----------------+---------------+---------------+--------------+---------------+-----------------+----------+------------------+------------------+---------------------+-----------------+-----------------------+-------------+----------------+----------------+-------------------+---------------+---------------------+
# only showing top 20 rows

# %% [markdown]
# ### Normaliser/scaler les features numériques.

# %%
from pyspark.ml.feature import VectorAssembler, StandardScaler

assembler = VectorAssembler(
    inputCols=["OrderItemTotal", "Type_vec", "ShippingMode_vec", "CategoryName_vec", "CustomerSegment_vec", "OrderRegion_vec", "ShippingMonthName_vec"],
    outputCol="features"
)

df_assembled = assembler.transform(df_encoded)

scaler = StandardScaler(
    inputCol="features",
    outputCol="scaled_features",
    withMean=True,
    withStd=True
)

scaler_model = scaler.fit(df_assembled)
df_scaled = scaler_model.transform(df_assembled)
